# %% [markdown]
# # 02 Windowing + Export

# %%
from pathlib import Path
import sys

ROOT_DIR = Path.cwd().resolve()
if not (ROOT_DIR / "data" / "raw").exists():
    ROOT_DIR = ROOT_DIR.parent
assert (ROOT_DIR / "data" / "raw").exists(), f"Set ROOT_DIR manually. Current guess: {ROOT_DIR}"
if str(ROOT_DIR) not in sys.path:
    sys.path.insert(0, str(ROOT_DIR))
ROOT_DIR

# %%
import pandas as pd
from tcrb_processing import notebook_02_windows_export

results = notebook_02_windows_export(ROOT_DIR)
results

# %%
pd.read_csv(ROOT_DIR / "figures" / "window_modern_counts.csv")

# %%
pd.read_csv(ROOT_DIR / "figures" / "window_1946_counts.csv")

# %%
pd.read_csv(ROOT_DIR / "figures" / "window_1866_coverage.csv")
