# %% [markdown]
# # 04 ASAS-SN Cross-check

# %%
from pathlib import Path
import sys

ROOT_DIR = Path.cwd().resolve()
if not (ROOT_DIR / "data" / "raw").exists():
    ROOT_DIR = ROOT_DIR.parent
assert (ROOT_DIR / "data" / "raw").exists(), f"Set ROOT_DIR manually. Current guess: {ROOT_DIR}"
if str(ROOT_DIR) not in sys.path:
    sys.path.insert(0, str(ROOT_DIR))
ROOT_DIR

# %%
from tcrb_processing import notebook_04_asassn_crosscheck

results = notebook_04_asassn_crosscheck(ROOT_DIR)
results

# %%
print((ROOT_DIR / "figures" / "asassn_qc_counts.txt").read_text())

# %%
print((ROOT_DIR / "notes" / "asassn_vs_aavso_overlap_metrics.txt").read_text())
