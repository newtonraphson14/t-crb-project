# %% [markdown]
# # 03 Binning + Smoothing

# %%
from pathlib import Path
import sys

ROOT_DIR = Path.cwd().resolve()
if not (ROOT_DIR / "data" / "raw").exists():
    ROOT_DIR = ROOT_DIR.parent
assert (ROOT_DIR / "data" / "raw").exists(), f"Set ROOT_DIR manually. Current guess: {ROOT_DIR}"
if str(ROOT_DIR) not in sys.path:
    sys.path.insert(0, str(ROOT_DIR))
ROOT_DIR

# %%
import pandas as pd
from tcrb_processing import notebook_03_binning_smoothing

results = notebook_03_binning_smoothing(ROOT_DIR)
results

# %%
pd.read_csv(ROOT_DIR / "figures" / "filter_counts_modern_window.csv")

# %%
pd.read_parquet(ROOT_DIR / "data" / "clean" / "modern_V_2015_2025_bin7d_rollmed5.parquet").head()

# %%
pd.read_parquet(ROOT_DIR / "data" / "clean" / "allcycles_Vis_1935_1955_bin7d.parquet").head()
